# %%
import pandas as pd

# %%
df=pd.read_csv('/diabetes_dataset.csv')

df.head()
# Out:
#     gender   age    location   race  hypertension  heart_disease  \
# 0   female  47.5     Gujarat  Asian             0              0
# 1   Female  26.5   Rajasthan  Other             0              0
# 2   female  23.9  Tamil Nadu  Other             0              0
# 3     male  52.4      Kerala  Black             0              0
# 4     male  29.8   Telangana  Asian             0              0
#
#   smoking_history   bmi  HbA1c_level  blood_glucose_level  diabetes
# 0           never  23.8          6.3                176.0         1
# 1           never  38.9          5.2                136.0         0
# 2         No Info  24.9          6.4                 65.0         1
# 3     not current  26.9          4.9                210.0         1
# 4           never  26.8          4.7                131.0         1

# %%
df.tail()
# Out:
#          gender   age       location      race  hypertension  heart_disease  \
# 101495     male  44.6  Uttar Pradesh     White             0              0
# 101496   Female  38.4      Telangana     Asian             0              0
# 101497   female  63.7      Telangana     Asian             0              0
# 101498   Female  66.9         Kerala  Hispanic             0              0
# 101499     MALE  32.7     Tamil Nadu     Asian             0              0
#
#        smoking_history   bmi  HbA1c_level  blood_glucose_level  diabetes
# 101495           never  30.2          5.6                 74.0         0
# 101496           never  17.4          3.6                169.0         0
# 101497     not current  29.7          4.1                125.0         1
# 101498           never  24.3          7.5                126.0         1
# 101499            ever  30.6          6.0                 98.0         1

# %%
df.shape[0]
# Out:
# 101500

# %%
df.shape[1]
# Out:
# 11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101500 entries, 0 to 101499
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               101500 non-null  object
#  1   age                  100483 non-null  float64
#  2   location             101500 non-null  object
#  3   race                 99972 non-null   object
#  4   hypertension         101500 non-null  int64
#  5   heart_disease        101500 non-null  int64
#  6   smoking_history      97439 non-null   object
#  7   bmi                  98455 non-null   float64
#  8   HbA1c_level          99468 non-null   float64
#  9   blood_glucose_level  98959 non-null   float64
#  10  diabetes             101500 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 8.5+ MB

# %%
df.isnull()
# Out:
#         gender    age  location   race  hypertension  heart_disease  \
# 0        False  False     False  False         False          False
# 1        False  False     False  False         False          False
# 2        False  False     False  False         False          False
# 3        False  False     False  False         False          False
# 4        False  False     False  False         False          False
# ...        ...    ...       ...    ...           ...            ...
# 101495   False  False     False  False         False          False
# 101496   False  False     False  False         False          False
# 101497   False  False     False  False         False          False
# 101498   False  False     False  False         False          False
# 101499   False  False     False  False         False          False
#
#         smoking_history    bmi  HbA1c_level  blood_glucose_level  diabetes
# 0                 False  False        False                False     False
# ...

# %%
df.isnull().sum()
# Out:
# gender                    0
# age                    1017
# location                  0
# race                   1528
# hypertension              0
# heart_disease             0
# smoking_history        4061
# bmi                    3045
# HbA1c_level            2032
# blood_glucose_level    2541
# diabetes                  0
# dtype: int64

# %%
df["age"]=df["age"].fillna(df["age"].mean())
df.isnull().sum()
# Out:
# gender                    0
# age                       0
# location                  0
# race                   1528
# hypertension              0
# heart_disease             0
# smoking_history        4061
# bmi                    3045
# HbA1c_level            2032
# blood_glucose_level    2541
# diabetes                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1498)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# location               0
# race                   0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87630 entries, 0 to 101499
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               87630 non-null  object
#  1   age                  87630 non-null  float64
#  2   location             87630 non-null  object
#  3   race                 87630 non-null  object
#  4   hypertension         87630 non-null  int64
#  5   heart_disease        87630 non-null  int64
#  6   smoking_history      87630 non-null  object
#  7   bmi                  87630 non-null  float64
#  8   HbA1c_level          87630 non-null  float64
#  9   blood_glucose_level  87630 non-null  float64
#  10  diabetes             87630 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 8.0+ MB

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  87630.000000  87630.000000   87630.000000  87630.000000  87630.000000
# mean      45.138319      0.149001       0.081753     26.971450      5.709683
# std       21.430091      0.356092       0.273989      6.225675      1.080612
# min       -5.000000      0.000000       0.000000      0.000000      3.500000
# 25%       31.600000      0.000000       0.000000     22.900000      5.000000
# 50%       45.157951      0.000000       0.000000     26.900000      5.700000
# 75%       58.300000      0.000000       0.000000     31.000000      6.400000
# max      999.000000      1.000000       1.000000    200.000000     10.300000
#
#        blood_glucose_level      diabetes
# count         87630.000000  87630.000000
# mean            138.224136      0.502568
# std              39.430159      0.499996
# min              50.000000      0.000000
# 25%             111.000000      0.000000
# ...

# %%
import numpy as np

# %%
data = df.to_numpy
print(data)
# Out:
# <bound method DataFrame.to_numpy of          gender   age       location      race  hypertension  heart_disease  \
# 0        female  47.5        Gujarat     Asian             0              0
# 1        Female  26.5      Rajasthan     Other             0              0
# 2        female  23.9     Tamil Nadu     Other             0              0
# 3          male  52.4         Kerala     Black             0              0
# 4          male  29.8      Telangana     Asian             0              0
# ...         ...   ...            ...       ...           ...            ...
# 101495     male  44.6  Uttar Pradesh     White             0              0
# 101496   Female  38.4      Telangana     Asian             0              0
# 101497   female  63.7      Telangana     Asian             0              0
# 101498   Female  66.9         Kerala  Hispanic             0              0
# 101499     MALE  32.7     Tamil Nadu     Asian             0              0
#
# ...

# %%
age = df["age"].to_numpy()

print("Mean age:", np.mean(age))
print("Median age:", np.median(age))
print("Minimum age:", np.min(age))
print("Maximum age:", np.max(age))
# Out:
# Mean age: 45.13831939711338
# Median age: 45.15795109620532
# Minimum age: -5.0
# Maximum age: 999.0

# %%
import pandas as pd
df=pd.read_csv('/diabetes_dataset.csv')
df.head()
# Out:
#     gender   age    location   race  hypertension  heart_disease  \
# 0   female  47.5     Gujarat  Asian             0              0
# 1   Female  26.5   Rajasthan  Other             0              0
# 2   female  23.9  Tamil Nadu  Other             0              0
# 3     male  52.4      Kerala  Black             0              0
# 4     male  29.8   Telangana  Asian             0              0
#
#   smoking_history   bmi  HbA1c_level  blood_glucose_level  diabetes
# 0           never  23.8          6.3                176.0         1
# 1           never  38.9          5.2                136.0         0
# 2         No Info  24.9          6.4                 65.0         1
# 3     not current  26.9          4.9                210.0         1
# 4           never  26.8          4.7                131.0         1

# %%
import matplotlib.pyplot as plt

counts = df["diabetes"].value_counts()
plt.bar(counts.index, counts.values)
plt.title("diabetes distribution")
plt.xlabel("diabetes")
plt.ylabel("no.of ppl")
plt.show()

# %%
import matplotlib.pyplot as plt

bins = [20,30,40,50,60,70,80]
labels = ['20-29','30-39','40-49','50-59','60-69','70-79']

df["age_group"] = pd.cut(df["age"], bins=bins, labels=labels, right=False)
diabetes_rate = df.groupby("age_group",observed=True)["diabetes"].mean()*100

plt.figure(figsize=(9,6))
plt.plot(diabetes_rate.index, diabetes_rate.values, marker='o', linewidth=2)
plt.title("Diabetes Prevalence By Age Group")
plt.xlabel("Age Group")
plt.ylabel("Diabetes Prevalence(%)")
plt.show()
